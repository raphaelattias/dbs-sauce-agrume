# %%
# %cd /content/CS-439-Optimization-for-ML
import torch
import matplotlib.pyplot as plt
from plot import plot_all_opt

from train import *

import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2
# Out:
# /content/CS-439-Optimization-for-ML
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !git clone https://raphaelattias:CoussinNoir1379@github.com/riccardocadei/CS-439-Optimization-for-ML.git
# !pip install torch_optimizer
# !pip3 install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio==0.9.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Cloning into 'CS-439-Optimization-for-ML'...
# remote: Enumerating objects: 238, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 238 (delta 27), reused 71 (delta 22), pack-reused 162
# Receiving objects: 100% (238/238), 1.14 GiB | 33.29 MiB/s, done.
# Resolving deltas: 100% (71/71), done.
# Checking out files: 100% (27/27), done.
# ...
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %% [markdown]
# # First Order Methods
# ## Stochastic Gradient Descent

# %%
SGD = run_experiment(optimizer_name="SGD", model_name='resnet18', 
                nb_epochs=15, batch_size=100, reduce=50, plot=True, lr=0.01)
# Out:
# Device used:  cuda
#
# Dataset: MNIST
# Training size:  1200
# Validation size:  200
# Test size:  200
# Dimension Images: 28x28
# Number of classes: 10
#
# Model:  Resnet18
# Number of parameters:  11175370
#
# Loss Function: Cross Entropy Loss
# Optimizer:  SGD
# Learning Rate:  0.01
#
# Epoch 1 / 15 train loss: 1.6721797188123066 valid loss: 2.234576106071472
# Epoch 2 / 15 train loss: 0.574525959789753 valid loss: 2.0156298875808716
# Epoch 3 / 15 train loss: 0.238155464331309 valid loss: 1.3052058815956116
# Epoch 4 / 15 train loss: 0.12730918327967325 valid loss: 0.7132019996643066
# Epoch 5 / 15 train loss: 0.08278634709616502 valid loss: 0.5281441062688828
# Epoch 6 / 15 train loss: 0.06017596088349819 valid loss: 0.48764514923095703
# Epoch 7 / 15 train loss: 0.04686910721162955 valid loss: 0.4680515229701996
# Epoch 8 / 15 train loss: 0.03811064797143141 valid loss: 0.45289798080921173
# Epoch 9 / 15 train loss: 0.03199647987882296 valid loss: 0.4409950375556946
# ...

# %% [markdown]
# ## Stochastic Gradient Descent + Momentum

# %%
SGDM = run_experiment(optimizer_name="SGD+Momentum", model_name='resnet18', 
                nb_epochs=15, batch_size=100, reduce=50, plot=True)
# Out:
# Device used:  cuda
#
# Dataset: MNIST
# Training size:  1200
# Validation size:  200
# Test size:  200
# Dimension Images: 28x28
# Number of classes: 10
#
# Model:  Resnet18
# Number of parameters:  11175370
#
# Loss Function: Cross Entropy Loss
# Optimizer:  SGD+Momentum
# Learning Rate:  0.005
#
# Epoch 1 / 15 train loss: 1.5106494079033534 valid loss: 2.153263211250305
# Epoch 2 / 15 train loss: 0.33755263810356456 valid loss: 1.7684692740440369
# Epoch 3 / 15 train loss: 0.06430350500158966 valid loss: 0.6944547742605209
# Epoch 4 / 15 train loss: 0.012731939166163405 valid loss: 0.22728744894266129
# Epoch 5 / 15 train loss: 0.0046875930080811186 valid loss: 0.16901026666164398
# Epoch 6 / 15 train loss: 0.0028625929165476314 valid loss: 0.1612274907529354
# Epoch 7 / 15 train loss: 0.0021539558559500924 valid loss: 0.15882975235581398
# Epoch 8 / 15 train loss: 0.0017950735054910183 valid loss: 0.157123614102602
# ...

# %% [markdown]
# ## Adam

# %%
Adam = run_experiment(optimizer_name="Adam", model_name='resnet18', 
                nb_epochs=15, batch_size=100, reduce=50, plot=True, lr=0.001)
# Out:
# Device used:  cuda
#
# Dataset: MNIST
# Training size:  1200
# Validation size:  200
# Test size:  200
# Dimension Images: 28x28
# Number of classes: 10
#
# Model:  Resnet18
# Number of parameters:  11175370
#
# Loss Function: Cross Entropy Loss
# Optimizer:  Adam
# Learning Rate:  0.001
#
# Epoch 1 / 15 train loss: 0.8726518427332243 valid loss: 1.9918283224105835
# Epoch 2 / 15 train loss: 0.19253326021134853 valid loss: 2.543077826499939
# Epoch 3 / 15 train loss: 0.051454210886731744 valid loss: 0.4142891466617584
# Epoch 4 / 15 train loss: 0.04050464113242924 valid loss: 0.27634505182504654
# Epoch 5 / 15 train loss: 0.011757504990479598 valid loss: 0.17729473114013672
# Epoch 6 / 15 train loss: 0.0043075435678474605 valid loss: 0.25134220719337463
# Epoch 7 / 15 train loss: 0.0035971175675513223 valid loss: 0.20950177311897278
# Epoch 8 / 15 train loss: 0.0012185761321840498 valid loss: 0.1588313952088356
# ...

# %% [markdown]
# # Second Order Methods
# ## AdaHessian

# %%
AdaHessian = run_experiment(optimizer_name="AdaHessian", model_name='resnet18', 
                nb_epochs=15, batch_size=100, reduce=50, plot=True, lr=0.1)
# Out:
# Device used:  cuda
#
# Dataset: MNIST
# Training size:  600
# Validation size:  100
# Test size:  100
# Dimension Images: 28x28
# Number of classes: 10
#
# Model:  Resnet18
# Number of parameters:  11175370
#
# Loss Function: Cross Entropy Loss
# Optimizer:  AdaHessian
# Learning Rate:  0.1
#
# Epoch 1 / 15 train loss: 1.6005250910917919 valid loss: 5.221242904663086
# Epoch 2 / 15 train loss: 0.24485899694263935 valid loss: 9.355820655822754
# Epoch 3 / 15 train loss: 0.04499988040576378 valid loss: 9.575757026672363
# Epoch 4 / 15 train loss: 0.013617919680352012 valid loss: 4.988393783569336
# Epoch 5 / 15 train loss: 0.007012416181775431 valid loss: 2.9571611881256104
# Epoch 6 / 15 train loss: 0.002802669031855961 valid loss: 1.17127525806427
# Epoch 7 / 15 train loss: 0.0018398211686871946 valid loss: 0.2987971901893616
# Epoch 8 / 15 train loss: 0.0013279703950198989 valid loss: 0.1664610058069229
# ...

# %% [markdown]
# # Hybrid Method
# ## SGDM + AdaHessian

# %%
Hybrid = run_experiment(optimizer_name="Hybrid", model_name='resnet18', 
                nb_epochs=15, batch_size=100, reduce=50, plot=True, lr=0.005)
# Out:
# Device used:  cuda
#
# Dataset: MNIST
# Training size:  1200
# Validation size:  200
# Test size:  200
# Dimension Images: 28x28
# Number of classes: 10
#
# Model:  Resnet18
# Number of parameters:  11175370
#
# Loss Function: Cross Entropy Loss
# Optimizer:  Hybrid
# Learning Rate:  0.005
#
# Epoch 1 / 15 train loss: 1.508645196755727 valid loss: 2.154068350791931
# Epoch 2 / 15 train loss: 0.3386166424800952 valid loss: 1.9095611572265625
# Epoch 3 / 15 train loss: 0.059233757123971977 valid loss: 0.7092122733592987
# Epoch 4 / 15 train loss: 0.01256501612563928 valid loss: 0.26443982869386673
# Epoch 5 / 15 train loss: 0.004308314353693277 valid loss: 0.17523784935474396
# Epoch 6 / 15 train loss: 0.002721749022991086 valid loss: 0.16399427130818367
# Epoch 7 / 15 train loss: 0.001952469280998533 valid loss: 0.16352153941988945
# Epoch 8 / 15 train loss: 0.001512236805865541 valid loss: 0.1635456308722496
# ...

# %% [markdown]
# # Comparaison of the optimizers

# %%
plot_all_opt(['SGD','SGD+Momentum','AdaHessian','Adam','Hybrid'], plot='val_losses')

# %%
plot_all_opt(['SGD','SGD+Momentum','AdaHessian','Adam','Hybrid'], plot='valid_acc')

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
best_return, best_hyperparameters = parameter_grid_search()
